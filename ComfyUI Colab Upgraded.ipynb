# %% [markdown]
# <a href="https://colab.research.google.com/github/Sihle3005/BMW-Sales-Analytics/blob/main/ComfyUI%20Colab%20Upgraded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⚡ ComfyUI: Professional Edition
#
# ### 🔴 **Brought to you by [AI With Chucky](https://youtube.com/@AIWithChucky)**
#
# ### 🖥️ **High-Performance AI Environment**
# This notebook provides a stable, persistent, and optimized environment for running ComfyUI on Google Colab.
#
# **Key Features:**
# - **Tarball SSD Caching:** UI nodes are packed into a single high-speed archive to bypass Google Drive's small-file bottleneck.
# - **Modern Downloader:** Python-native, high-speed downloader with visual progress bars.
# - **Memory Safety:** Prevents OOM (Out of Memory) errors via selectable GPU profiles.

# %%
#@title 1. System Initialization
#@markdown **Run this cell first.** <br>
#@markdown Mounts Drive, sets up ComfyUI, and extracts your high-speed Tarball cache to the local SSD for instant booting.

import os
import shutil
import subprocess
import sys
from google.colab import drive

print("[SYSTEM] Initialization Protocol Started...\n")

# --- Configuration ---
MOUNT_DRIVE = True
UPDATE_COMFY_UI = False #@param {type:"boolean"}
INSTALL_COMFYUI_MANAGER = True #@param {type:"boolean"}

LOCAL_WORKSPACE = "/content/ComfyUI"
DRIVE_WORKSPACE = "/content/drive/MyDrive/ComfyUI"
CACHE_TAR = os.path.join(DRIVE_WORKSPACE, "comfy_ui_cache.tar")

def stream_cmd(cmd, cwd=None):
    """Streams shell commands directly to the output"""
    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, cwd=cwd, bufsize=1)
    for line in iter(process.stdout.readline, ''):
        sys.stdout.write(line)
        sys.stdout.flush()

# 1. Mount Google Drive
if MOUNT_DRIVE:
    print("💾 Requesting Google Drive Access (Check popup if not already mounted)...")
    drive.mount('/content/drive')

# 2. Setup ComfyUI Core
if not os.path.exists(LOCAL_WORKSPACE):
    print("\n📦 Cloning ComfyUI repository...")
    subprocess.run(["git", "clone", "https://github.com/comfyanonymous/ComfyUI", LOCAL_WORKSPACE])
else:
    if UPDATE_COMFY_UI:
        print("\n🔄 Checking for ComfyUI updates...")
        subprocess.run(["git", "pull"], cwd=LOCAL_WORKSPACE)

# 3. Configure Hybrid Storage & Tarball Cache
heavy_dirs = ["models", "output", "input"]
print("\n🔗 Routing heavy model directories directly to Drive...")
for d in heavy_dirs:
    local_path = os.path.join(LOCAL_WORKSPACE, d)
    drive_path = os.path.join(DRIVE_WORKSPACE, d)
    if not os.path.exists(drive_path): os.makedirs(drive_path, exist_ok=True)
    if os.path.exists(local_path) and not os.path.islink(local_path): shutil.rmtree(local_path)
    if not os.path.exists(local_path): os.symlink(drive_path, local_path)

print("\n⚡ Deploying High-Speed Tarball Cache for UI Elements...")
if os.path.exists(CACHE_TAR):
    print("   📦 Extracting cached UI nodes to local SSD (Superfast)...")
    os.system(f"tar -xf '{CACHE_TAR}' -C '{LOCAL_WORKSPACE}' > /dev/null 2>&1")
else:
    print("   ⚠️ No cache found on Drive. Creating fresh local directories...")
    os.makedirs(os.path.join(LOCAL_WORKSPACE, "custom_nodes"), exist_ok=True)
    os.makedirs(os.path.join(LOCAL_WORKSPACE, "user"), exist_ok=True)

# 4. Install ComfyUI Manager
if INSTALL_COMFYUI_MANAGER:
    manager_path = os.path.join(LOCAL_WORKSPACE, "custom_nodes", "ComfyUI-Manager")
    if not os.path.exists(manager_path):
        print("\n📦 Installing ComfyUI Manager...")
        subprocess.run(["git", "clone", "https://github.com/ltdrdata/ComfyUI-Manager.git", manager_path])
    else:
        print("\n✅ ComfyUI Manager verified.")
        subprocess.run(["git", "pull"], cwd=manager_path)

# 5. Core Python Dependencies
print("\n🛠️ Installing base Python requirements...")
stream_cmd(["pip", "install", "xformers!=0.0.18", "-r", "requirements.txt", "--extra-index-url", "https://download.pytorch.org/whl/cu121"], cwd=LOCAL_WORKSPACE)
stream_cmd(["pip", "install", "insightface", "onnxruntime-gpu"])

# 6. AUTO-HEAL: Custom Node Dependencies
print("\n🔍 [AUTO-HEAL] Scanning local custom nodes for missing dependencies...")
custom_nodes_dir = os.path.join(LOCAL_WORKSPACE, "custom_nodes")
if os.path.exists(custom_nodes_dir):
    for item in os.listdir(custom_nodes_dir):
        node_path = os.path.join(custom_nodes_dir, item)
        req_file = os.path.join(node_path, "requirements.txt")
        if os.path.isdir(node_path) and os.path.exists(req_file):
            print(f"\n   ⚙️ Restoring dependencies for: {item}")
            stream_cmd(["pip", "install", "-r", "requirements.txt"], cwd=node_path)

print("\n✅ [SYSTEM READY] Initialization complete.")
# Out:
# [SYSTEM] Initialization Protocol Started...
#
# 💾 Requesting Google Drive Access (Check popup if not already mounted)...
# Mounted at /content/drive
#
# 📦 Cloning ComfyUI repository...
#
# 🔗 Routing heavy model directories directly to Drive...
#
# ⚡ Deploying High-Speed Tarball Cache for UI Elements...
#    ⚠️ No cache found on Drive. Creating fresh local directories...
#
# 📦 Installing ComfyUI Manager...
#
# 🛠️ Installing base Python requirements...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# Collecting xformers!=0.0.18
#   Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting comfyui-frontend-package==1.43.18 (from -r requirements.txt (line 1))
#   Downloading comfyui_frontend_package-1.43.18-py3-none-any.whl.metadata (118 bytes)
# Collecting comfyui-workflow-templates==0.9.73 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.9.73-py3-none-any.whl.metadata (23 kB)
# Collecting comfyui-embedded-docs==0.4.4 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.4.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.10.0+cu128)
# Collecting torchsde (from -r requirements.txt (line 5))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.25.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (5.0.0)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.2.1)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.13.5)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (1.18.4)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (2.0.49)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.29.0)
# Collecting av>=14.2.0 (from -r requirements.txt (line 24))
#   Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting comfy-kitchen>=0.2.8 (from -r requirements.txt (line 25))
#   Downloading comfy_kitchen-0.2.8-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Collecting comfy-aimdo==0.3.0 (from -r requirements.txt (line 26))
#   Downloading comfy_aimdo-0.3.0-cp39-abi3-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (2.32.4)
# Collecting simpleeval>=1.0.0 (from -r requirements.txt (line 28))
#   Downloading simpleeval-1.0.7-py3-none-any.whl.metadata (20 kB)
# Collecting blake3 (from -r requirements.txt (line 29))
#   Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting kornia>=0.7.1 (from -r requirements.txt (line 32))
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting spandrel (from -r requirements.txt (line 33))
#   Downloading spandrel-0.4.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (2.12.3)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (2.14.0)
# Requirement already satisfied: PyOpenGL in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (3.1.10)
# Collecting glfw (from -r requirements.txt (line 37))
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting comfyui-workflow-templates-core==0.3.229 (from comfyui-workflow-templates==0.9.73->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_core-0.3.229-py3-none-any.whl.metadata (260 bytes)
# Collecting comfyui-workflow-templates-media-api==0.3.75 (from comfyui-workflow-templates==0.9.73->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_api-0.3.75-py3-none-any.whl.metadata (290 bytes)
# Collecting comfyui-workflow-templates-media-video==0.3.85 (from comfyui-workflow-templates==0.9.73->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_video-0.3.85-py3-none-any.whl.metadata (282 bytes)
# Collecting comfyui-workflow-templates-media-image==0.3.138 (from comfyui-workflow-templates==0.9.73->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_image-0.3.138-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-other==0.3.195 (from comfyui-workflow-templates==0.9.73->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_other-0.3.195-py3-none-any.whl.metadata (306 bytes)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 4)) (1.5.3)
# Collecting trampoline>=0.1.2 (from torchsde->-r requirements.txt (line 5))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (26.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (0.24.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.4.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.13)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->-r requirements.txt (line 21)) (1.3.11)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=2.0.0->-r requirements.txt (line 22)) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2026.4.22)
# Collecting kornia_rs>=0.1.9 (from kornia>=0.7.1->-r requirements.txt (line 32))
#   Downloading kornia_rs-0.1.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->-r requirements.txt (line 35)) (1.2.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.24.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.1.2)
# Downloading comfyui_frontend_package-1.43.18-py3-none-any.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 56.2 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates-0.9.73-py3-none-any.whl (10 kB)
# Downloading comfyui_embedded_docs-0.4.4-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 97.9 MB/s eta 0:00:00
# Downloading comfy_aimdo-0.3.0-cp39-abi3-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 16.8 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_core-0.3.229-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 6.1 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_api-0.3.75-py3-none-any.whl (74.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 MB 9.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_image-0.3.138-py3-none-any.whl (73.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 MB 12.4 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_other-0.3.195-py3-none-any.whl (65.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 MB 12.1 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_video-0.3.85-py3-none-any.whl (94.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 MB 9.1 MB/s eta 0:00:00
# Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 115.7 MB/s eta 0:00:00
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.1 MB/s eta 0:00:00
# Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 67.1 MB/s eta 0:00:00
# Downloading comfy_kitchen-0.2.8-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (794 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 794.6/794.6 kB 55.0 MB/s eta 0:00:00
# Downloading simpleeval-1.0.7-py3-none-any.whl (18 kB)
# Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 36.1 MB/s eta 0:00:00
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 74.0 MB/s eta 0:00:00
# Downloading spandrel-0.4.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.8/320.8 kB 27.5 MB/s eta 0:00:00
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 23.8 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 128.7 MB/s eta 0:00:00
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: trampoline, glfw, simpleeval, kornia_rs, comfyui-workflow-templates-media-video, comfyui-workflow-templates-media-other, comfyui-workflow-templates-media-image, comfyui-workflow-templates-media-api, comfyui-workflow-templates-core, comfyui-frontend-package, comfyui-embedded-docs, comfy-kitchen, comfy-aimdo, blake3, av, comfyui-workflow-templates, xformers, torchsde, kornia, spandrel
# Successfully installed av-17.0.1 blake3-1.0.8 comfy-aimdo-0.3.0 comfy-kitchen-0.2.8 comfyui-embedded-docs-0.4.4 comfyui-frontend-package-1.43.18 comfyui-workflow-templates-0.9.73 comfyui-workflow-templates-core-0.3.229 comfyui-workflow-templates-media-api-0.3.75 comfyui-workflow-templates-media-image-0.3.138 comfyui-workflow-templates-media-other-0.3.195 comfyui-workflow-templates-media-video-0.3.85 glfw-2.10.0 kornia-0.8.2 kornia_rs-0.1.11 simpleeval-1.0.7 spandrel-0.4.2 torchsde-0.2.6 trampoline-0.1.2 xformers-0.0.35
# Collecting insightface
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 33.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.2)
# Collecting onnx (from insightface)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from insightface) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from insightface) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from insightface) (3.10.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from insightface) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from insightface) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from insightface) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from insightface) (0.25.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from insightface) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from insightface) (3.0.12)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.8)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from insightface) (3.17.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (26.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (0.5.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->insightface) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2026.4.22)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.17.0)
# Downloading onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (277.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 1.6 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 42.5 MB/s eta 0:00:00
# Building wheels for collected packages: insightface
#   Building wheel for insightface (pyproject.toml): started
#   Building wheel for insightface (pyproject.toml): finished with status 'done'
#   Created wheel for insightface: filename=insightface-0.7.3-cp312-cp312-linux_x86_64.whl size=1071486 sha256=e9aa19a9d381836659777b4395e87d555582e2498c96996e76b78c6574f4e013
#   Stored in directory: /root/.cache/pip/wheels/73/3c/e2/6d4815e8a8b33a2006554d65ce0d1f973e768f4c7a222fa675
# Successfully built insightface
# Installing collected packages: onnxruntime-gpu, onnx, insightface
# Successfully installed insightface-0.7.3 onnx-1.21.0 onnxruntime-gpu-1.26.0
#
# 🔍 [AUTO-HEAL] Scanning local custom nodes for missing dependencies...
#
#    ⚙️ Restoring dependencies for: ComfyUI-Manager
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (3.1.47)
# Collecting PyGithub (from -r requirements.txt (line 2))
#   Downloading pygithub-2.9.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting matrix-nio (from -r requirements.txt (line 3))
#   Downloading matrix_nio-0.25.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.24.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.10.2)
# Collecting uv (from -r requirements.txt (line 10))
#   Downloading uv-0.11.12-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (5.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->-r requirements.txt (line 1)) (4.0.12)
# Collecting pynacl>=1.4.0 (from PyGithub->-r requirements.txt (line 2))
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub->-r requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->-r requirements.txt (line 2)) (2.12.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: aiohttp~=3.10 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r requirements.txt (line 3)) (3.13.5)
# Requirement already satisfied: aiofiles~=24.1 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r requirements.txt (line 3)) (24.1.0)
# Requirement already satisfied: h11~=0.14 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: h2~=4.0 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r requirements.txt (line 3)) (4.3.0)
# Requirement already satisfied: jsonschema~=4.14 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r requirements.txt (line 3)) (4.26.0)
# Collecting unpaddedbase64~=2.1 (from matrix-nio->-r requirements.txt (line 3))
#   Downloading unpaddedbase64-2.1.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting pycryptodome~=3.10 (from matrix-nio->-r requirements.txt (line 3))
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting aiohttp-socks~=0.8 (from matrix-nio->-r requirements.txt (line 3))
#   Downloading aiohttp_socks-0.11.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (3.29.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 5)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->-r requirements.txt (line 6)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->-r requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->-r requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r requirements.txt (line 3)) (1.23.0)
# Collecting python-socks<3.0.0,>=2.4.3 (from python-socks[asyncio]<3.0.0,>=2.4.3->aiohttp-socks~=0.8->matrix-nio->-r requirements.txt (line 3))
#   Downloading python_socks-2.8.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython->-r requirements.txt (line 1)) (5.0.3)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2~=4.0->matrix-nio->-r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2~=4.0->matrix-nio->-r requirements.txt (line 3)) (4.1.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->-r requirements.txt (line 5)) (3.13)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.14->matrix-nio->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.14->matrix-nio->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.14->matrix-nio->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->-r requirements.txt (line 2)) (43.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pynacl>=1.4.0->PyGithub->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.14.0->PyGithub->-r requirements.txt (line 2)) (3.4.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->pynacl>=1.4.0->PyGithub->-r requirements.txt (line 2)) (3.0)
# Downloading pygithub-2.9.1-py3-none-any.whl (449 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.7/449.7 kB 31.9 MB/s eta 0:00:00
# Downloading matrix_nio-0.25.2-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 18.1 MB/s eta 0:00:00
# Downloading uv-0.11.12-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 66.6 MB/s eta 0:00:00
# Downloading aiohttp_socks-0.11.0-py3-none-any.whl (10 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 72.4 MB/s eta 0:00:00
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.7 MB/s eta 0:00:00
# Downloading unpaddedbase64-2.1.0-py3-none-any.whl (6.1 kB)
# Downloading python_socks-2.8.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: uv, unpaddedbase64, python-socks, pycryptodome, pynacl, aiohttp-socks, PyGithub, matrix-nio
# Successfully installed PyGithub-2.9.1 aiohttp-socks-0.11.0 matrix-nio-0.25.2 pycryptodome-3.23.0 pynacl-1.6.2 python-socks-2.8.1 unpaddedbase64-2.1.0 uv-0.11.12
#
# ✅ [SYSTEM READY] Initialization complete.

# %%
#@title 2. Model & Node Downloader
#@markdown Paste download links below. This supports **Checkpoints, Diffusion Models (Flux/UNET), Text Encoders (CLIP/T5), CLIP Vision, VAEs, LoRAs, and ControlNets**.

import os
import requests
from urllib.parse import urlparse, unquote
from tqdm.auto import tqdm

WORKSPACE = "/content/ComfyUI"

# --- Input Resources ---
CHECKPOINT_URLS = "" #@param {type:"string"}
UNET_DIFFUSION_URLS = "https://huggingface.co/tianweiy/DMD2/resolve/main/dmd2_sdxl_4step_lora_fp16.safetensors" #@param {type:"string"}
TEXT_ENCODER_URLS = "" #@param {type:"string"}
CLIP_VISION_URLS = "" #@param {type:"string"}
VAE_URLS = "" #@param {type:"string"}
LORA_URLS = "" #@param {type:"string"}
CONTROLNET_URLS = "" #@param {type:"string"}
UPSCALE_MODELS_URLS = "" #@param {type:"string"}
EMBEDDING_URLS = "" #@param {type:"string"}
CUSTOM_NODE_URLS = "" #@param {type:"string"}

# --- Downloader Logic ---
DIRS = {
    "checkpoints":    os.path.join(WORKSPACE, "models/checkpoints"),
    "unet":           os.path.join(WORKSPACE, "models/unet"),
    "clip":           os.path.join(WORKSPACE, "models/clip"),
    "clip_vision":    os.path.join(WORKSPACE, "models/clip_vision"),
    "vae":            os.path.join(WORKSPACE, "models/vae"),
    "loras":          os.path.join(WORKSPACE, "models/loras"),
    "controlnet":     os.path.join(WORKSPACE, "models/controlnet"),
    "upscale_models": os.path.join(WORKSPACE, "models/upscale_models"),
    "embeddings":     os.path.join(WORKSPACE, "models/embeddings"),
    "custom_nodes":   os.path.join(WORKSPACE, "custom_nodes")
}

def get_filename(url, response):
    """Smartly determines filename from Content-Disposition or URL."""
    if "Content-Disposition" in response.headers:
        import re
        fname = re.findall('filename="?([^"]+)"?', response.headers["Content-Disposition"])
        if fname: return fname[0]
    return unquote(os.path.basename(urlparse(url).path))

def download_file(url, target_dir):
    try:
        # Stream the download to get headers first
        response = requests.get(url, stream=True, allow_redirects=True)
        response.raise_for_status()

        filename = get_filename(url, response)
        file_path = os.path.join(target_dir, filename)
        total_size = int(response.headers.get('content-length', 0))

        if os.path.exists(file_path):
            print(f"   ⏩ Skipping (Exists): {filename}")
            return

        # Modern Progress Bar Log
        print(f"   📥 Downloading: {filename}")

        # The Progress Bar (Auto-Stretching)
        with tqdm(
            total=total_size,
            unit='B',
            unit_scale=True,
            unit_divisor=1024,
            desc="      🚀 Progress",
            dynamic_ncols=True
        ) as bar:
            with open(file_path, 'wb') as f:
                for chunk in response.iter_content(chunk_size=1024*1024): # 1MB chunks
                    if chunk:
                        f.write(chunk)
                        bar.update(len(chunk))

        print("      ✅ Download Complete\n")

    except Exception as e:
        print(f"   ❌ Failed to download: {url}")
        print(f"      Error: {e}\n")

def process_downloads(urls_str, target_dir, is_node=False):
    if not urls_str.strip(): return

    url_list = [u.strip() for u in urls_str.replace(',', '\n').split('\n') if u.strip()]
    if not os.path.exists(target_dir): os.makedirs(target_dir, exist_ok=True)

    print(f"📂 Category: {os.path.basename(target_dir)}")

    for url in url_list:
        if is_node:
            node_name = url.split('/')[-1].replace('.git', '')
            node_path = os.path.join(target_dir, node_name)
            if not os.path.exists(node_path):
                print(f"   ⬇️ Cloning Node: {node_name}...")
                # !git clone {url} {node_path}
                # Auto-install requirements
                req = os.path.join(node_path, "requirements.txt")
                if os.path.exists(req):
                    print(f"      📦 Installing requirements...")
                    # !pip install -r "{req}"
                print("      ✅ Installed\n")
            else:
                print(f"   ⏩ Node exists: {node_name}\n")
        else:
            download_file(url, target_dir)

# --- Execution ---
process_downloads(CHECKPOINT_URLS,     DIRS["checkpoints"])
process_downloads(UNET_DIFFUSION_URLS, DIRS["unet"])
process_downloads(TEXT_ENCODER_URLS,   DIRS["clip"])
process_downloads(CLIP_VISION_URLS,    DIRS["clip_vision"])
process_downloads(VAE_URLS,            DIRS["vae"])
process_downloads(LORA_URLS,           DIRS["loras"])
process_downloads(CONTROLNET_URLS,     DIRS["controlnet"])
process_downloads(UPSCALE_MODELS_URLS, DIRS["upscale_models"])
process_downloads(EMBEDDING_URLS,      DIRS["embeddings"])
process_downloads(CUSTOM_NODE_URLS,    DIRS["custom_nodes"], is_node=True)

print("🎉 All tasks finished.")
# Out:
# 📂 Category: unet
#    📥 Downloading: dmd2_sdxl_4step_lora_fp16.safetensors
#       🚀 Progress:   0%|          | 0.00/376M [00:00<?, ?B/s]
#       ✅ Download Complete
#
# 🎉 All tasks finished.

# %%
# !wget https://github.com/AconexOfficial/ComfyUI_GOAT_Nodes/blob/main/nodes/fast_film_grain.py
# Out:
# --2026-05-10 15:15:22--  https://github.com/AconexOfficial/ComfyUI_GOAT_Nodes/blob/main/nodes/fast_film_grain.py
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘fast_film_grain.py’
#
# fast_film_grain.py      [ <=>                ] 359.35K  --.-KB/s    in 0.007s
#
# 2026-05-10 15:15:23 (49.5 MB/s) - ‘fast_film_grain.py’ saved [367974]

# %%
# @title 3. Session Anti-Disconnect
# %%html
<b>🔊 Keep-Alive Audio</b><br>
<i>Running this silent audio loop prevents the browser tab from sleeping.</i><br>
<audio src="https://raw.githubusercontent.com/anars/blank-audio/master/10-minutes-of-silence.mp3" autoplay loop controls style="width: 300px;" />
# Out:
# <b>🔊 Keep-Alive Audio</b><br>
# <i>Running this silent audio loop prevents the browser tab from sleeping.</i><br>
# <audio src="https://raw.githubusercontent.com/anars/blank-audio/master/10-minutes-of-silence.mp3" autoplay loop controls style="width: 300px;" />

# %%
#@title 4. Start ComfyUI Session
#@markdown Installs missing runtime dependencies, establishes an optimized IPv4 Cloudflare tunnel, and launches the ComfyUI web interface with live standard logs.

import subprocess
import threading
import time
import socket
import os
import sys

# --- Session Configuration ---
#@markdown **Performance Profile:**
MEMORY_PROFILE = "Low VRAM (T4 GPU / Heavy Models)" #@param ["Standard (Auto-Detect)", "Low VRAM (T4 GPU / Heavy Models)", "High VRAM (A100 GPU Only)"]
#@markdown **Visual Settings:**
LIVE_GENERATION_PREVIEWS = True #@param {type:"boolean"}

WORKSPACE = "/content/ComfyUI"
ARGS = []

if "Low VRAM" in MEMORY_PROFILE:
    ARGS.append("--lowvram")
elif "High VRAM" in MEMORY_PROFILE:
    ARGS.append("--highvram")

if LIVE_GENERATION_PREVIEWS:
    ARGS.extend(["--preview-method", "auto"])

# 0. Auto-Heal Missing Custom Node Dependencies
print("[SYSTEM] Auto-healing runtime dependencies...")
os.system("pip install -q gguf piexif > /dev/null 2>&1")

# 1. Initialize Network Tunnel
print("[SYSTEM] Verifying Cloudflare Daemon...")
if not os.path.exists("/usr/bin/cloudflared"):
    print("[SYSTEM] Fetching Cloudflared via aria2c...")
    os.system("apt-get install -y aria2 > /dev/null 2>&1")
    os.system("aria2c -x 16 -s 16 -k 1M https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb -d /content -o cloudflared.deb > /dev/null 2>&1")
    os.system("dpkg -i /content/cloudflared.deb > /dev/null 2>&1")

def start_tunnel(port):
    while True:
        time.sleep(1)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        sock.close()
        if result == 0:
            break

    print("\n[SYSTEM] ComfyUI Local Server Detected. Establishing Secure Tunnel...")

    p = subprocess.Popen(
        ["cloudflared", "tunnel", "--url", f"http://127.0.0.1:{port}", "--edge-ip-version", "4", "--protocol", "http2"],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True
    )

    tunnel_established = False
    for line in p.stderr:
        if "trycloudflare.com" in line and not tunnel_established:
            parts = line.split()
            for part in parts:
                if "trycloudflare.com" in part and part.startswith("http"):
                    url = part.strip()
                    print("\n" + "="*60)
                    print(f"🚀 ACTIVE TUNNEL: {url}")
                    print("="*60 + "\n")
                    tunnel_established = True
                    break

threading.Thread(target=start_tunnel, daemon=True, args=(8188,)).start()

# 2. Launch Application
if os.path.exists(os.path.join(WORKSPACE, "main.py")):
    os.chdir(WORKSPACE)
    print(f"[SYSTEM] Booting ComfyUI [Profile: {MEMORY_PROFILE}]")
    print("[SYSTEM] Streaming Logs...\n" + "-"*60)

    cmd = ["python", "main.py", "--listen", "127.0.0.1", "--port", "8188"] + ARGS
    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)

    for line in iter(process.stdout.readline, ''):
        sys.stdout.write(line)
        sys.stdout.flush()
else:
    print("[FATAL ERROR] ComfyUI directory missing. Please re-run the initialization cell.")
# Out:
# [SYSTEM] Auto-healing runtime dependencies...
# [SYSTEM] Verifying Cloudflare Daemon...
# [SYSTEM] Booting ComfyUI [Profile: Low VRAM (T4 GPU / Heavy Models)]
# [SYSTEM] Streaming Logs...
# ------------------------------------------------------------
# setup plugin alembic.autogenerate.schemas
# setup plugin alembic.autogenerate.tables
# setup plugin alembic.autogenerate.types
# setup plugin alembic.autogenerate.constraints
# setup plugin alembic.autogenerate.defaults
# setup plugin alembic.autogenerate.comments
# [ComfyUI-Manager] Using `uv` as Python module for pip operations.
# Using Python 3.12.13 environment at: /usr
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-05-10 14:55:55.408
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# Using Python 3.12.13 environment at: /usr
# Using Python 3.12.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    2.2 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Checkpoint files will always be loaded safely.
# Total VRAM 14913 MB, total RAM 12976 MB
# pytorch version: 2.10.0+cu128
# xformers version: 0.0.35
# Set vram state to: LOW_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using async weight offloading with 2 streams
# Enabled pinned memory 11677.0
# working around nvidia conv3d memory bug.
# Using xformers attention
# aimdo: /project/src-posix/cuda-funchooks.c:52:DEBUG:aimdo_setup_hooks: hooks successfully installed
# aimdo: /project/src/control.c:151:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14912 MB)
# DynamicVRAM support detected and enabled
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ComfyUI version: 0.20.1
# comfy-aimdo version: 0.3.0
# comfy-kitchen version: 0.2.8
# ComfyUI frontend version: 1.43.18
# [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# Asset seeder disabled
# ### Loading: ComfyUI-Impact-Subpack (V1.3.5)
# [Impact Pack/Subpack] Using folder_paths to determine whitelist path: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Pack/Subpack] Ensured whitelist directory exists: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack
# [Impact Pack/Subpack] Loaded 0 model(s) from whitelist: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Subpack] ultralytics_bbox: /content/ComfyUI/models/ultralytics/bbox
# [Impact Subpack] ultralytics_segm: /content/ComfyUI/models/ultralytics/segm
# ### Loading: ComfyUI-Manager (V3.40)
# [ComfyUI-Manager] network_mode: public
# [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# ### ComfyUI Version: v0.20.1-103-gaa9d2fc7 | Released on '2026-05-10'
#
# [rgthree-comfy] Loaded 48 epic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# ### Loading: ComfyUI-Impact-Pack (V8.28.3)
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [Impact Pack] Wildcard total size (0.00 MB) is within cache limit (50.00 MB). Using full cache mode.
# [Impact Pack] Wildcards loading done.
#
# Import times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-flux-continuum
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui_fearnworksnodes
#    0.1 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    0.1 seconds: /content/ComfyUI/custom_nodes/comfyui_essentials
#    0.3 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#    0.3 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-subpack
#    0.9 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-pack
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
#
# [SYSTEM] ComfyUI Local Server Detected. Establishing Secure Tunnel...
# FETCH ComfyRegistry Data: 5/145
#
# ============================================================FETCH ComfyRegistry Data: 10/145
#
# 🚀 ACTIVE TUNNEL: https://correctly-border-disco-kruger.trycloudflare.com
# ============================================================
#
# FETCH ComfyRegistry Data: 15/145
# FETCH ComfyRegistry Data: 20/145
# FETCH ComfyRegistry Data: 25/145
# FETCH ComfyRegistry Data: 30/145
# FETCH ComfyRegistry Data: 35/145
# FETCH ComfyRegistry Data: 40/145
# FETCH ComfyRegistry Data: 45/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/groupNode.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/clipspace.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 50/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/buttonGroup.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/button.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 55/145
# FETCH ComfyRegistry Data: 60/145
# FETCH ComfyRegistry Data: 65/145
# FETCH ComfyRegistry Data: 70/145
# FETCH ComfyRegistry Data: 75/145
# FETCH ComfyRegistry Data: 80/145
# FETCH ComfyRegistry Data: 85/145
# FETCH ComfyRegistry Data: 90/145
# FETCH ComfyRegistry Data: 95/145
# FETCH ComfyRegistry Data: 100/145
# FETCH ComfyRegistry Data: 105/145
# FETCH ComfyRegistry Data: 110/145
# FETCH ComfyRegistry Data: 115/145
# FETCH ComfyRegistry Data: 120/145
# FETCH ComfyRegistry Data: 125/145
# FETCH ComfyRegistry Data: 130/145
# FETCH ComfyRegistry Data: 135/145
# FETCH ComfyRegistry Data: 140/145
# FETCH ComfyRegistry Data: 145/145
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# got prompt
# invalid prompt: {'type': 'missing_node_type', 'message': "Node 'ID #182' has no class_type. The workflow may be corrupted or a custom node is missing.", 'details': "Node ID '#182'", 'extra_info': {'node_id': '182', 'class_type': None, 'node_title': None}}
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# Using Python 3.12.13 environment at: /usr
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# [ComfyUI-Manager] Updating ComfyUI: nightly -> v0.20.3
# Install: pip packages
# Using Python 3.12.13 environment at: /usr
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'comfyui-frontend-package==1.42.15']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Resolved 1 package in 100ms
# [!] Prepared 1 package in 313ms
# [!] Uninstalled 1 package in 32ms
# [!] Installed 1 package in 14ms
# [!]  - comfyui-frontend-package==1.43.18
# [!]  + comfyui-frontend-package==1.42.15
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'comfyui-workflow-templates==0.9.72']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Resolved 6 packages in 125ms
# [!] Prepared 5 packages in 3.04s
# [!] Uninstalled 5 packages in 111ms
# [!] Installed 5 packages in 21ms
# [!]  - comfyui-workflow-templates==0.9.73
# [!]  + comfyui-workflow-templates==0.9.72
# [!]  - comfyui-workflow-templates-core==0.3.229
# [!]  + comfyui-workflow-templates-core==0.3.228
# [!]  - comfyui-workflow-templates-media-image==0.3.138
# [!]  + comfyui-workflow-templates-media-image==0.3.137
# [!]  - comfyui-workflow-templates-media-other==0.3.195
# [!]  + comfyui-workflow-templates-media-other==0.3.194
# [!]  - comfyui-workflow-templates-media-video==0.3.85
# [!]  + comfyui-workflow-templates-media-video==0.3.84
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'comfyui-embedded-docs==0.4.4']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 25ms
# [ComfyUI-Manager] skip black listed pip installation: 'torch'
# [ComfyUI-Manager] skip black listed pip installation: 'torchsde'
# [ComfyUI-Manager] skip black listed pip installation: 'torchvision'
# [ComfyUI-Manager] skip black listed pip installation: 'torchaudio'
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numpy>=1.25.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 18ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'einops']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 20ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'transformers>=4.50.3']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 31ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'tokenizers>=0.13.3']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 20ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'sentencepiece']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 25ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'safetensors>=0.4.2']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 15ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'aiohttp>=3.11.8']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 98ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'yarl>=1.18.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 19ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pyyaml']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 24ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'Pillow']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 21ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scipy']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 16ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'tqdm']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 14ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'psutil']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 17ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'alembic']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 59ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'SQLAlchemy>=2.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 19ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'filelock']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 15ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'av>=14.2.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 21ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'comfy-kitchen>=0.2.8']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 25ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'comfy-aimdo==0.2.14']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Resolved 1 package in 103ms
# [!] Prepared 1 package in 9ms
# [!] Uninstalled 1 package in 2ms
# [!] Installed 1 package in 2ms
# [!]  - comfy-aimdo==0.3.0
# [!]  + comfy-aimdo==0.2.14
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'requests']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 18ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'simpleeval>=1.0.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 21ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'blake3']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 29ms
# Line is comment...skipping
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'kornia>=0.7.1']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 19ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'spandrel']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 36ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pydantic~=2.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 17ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pydantic-settings~=2.0']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 22ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'PyOpenGL']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 21ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'glfw']
# [!] Using Python 3.12.13 environment at: /usr
# [!] Checked 1 package in 25ms
# Using Python 3.12.13 environment at: /usr
# ComfyUI is updated to latest stable version.
#
# Updating: comfyui_fearnworksnodesERROR: To use this feature, you must either set '--listen' to a local IP and set the security level to 'normal-' or lower, or set the security level to 'middle' or 'weak'. Please contact the administrator.
# Reference: https://github.com/ltdrdata/ComfyUI-Manager#security-policy
#
# Updating: comfyui_essentials
# Updating: comfyui-impact-subpack
# Updating: comfyui-flux-continuum
# Updating: comfyui-manager
# Updating: rgthree-comfy
# Updating: comfyui-impact-pack
# [ComfyUI-Manager] Queued works are completed.
# {'update-comfyui': 1, 'update-main': 7}
#
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--listen', '127.0.0.1', '--port', '8188', '--lowvram', '--preview-method', 'auto']
# setup plugin alembic.autogenerate.schemas
# setup plugin alembic.autogenerate.tables
# setup plugin alembic.autogenerate.types
# setup plugin alembic.autogenerate.constraints
# setup plugin alembic.autogenerate.defaults
# setup plugin alembic.autogenerate.comments
# [ComfyUI-Manager] Using `uv` as Python module for pip operations.
# Using Python 3.12.13 environment at: /usr
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-05-10 15:02:13.808
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# Using Python 3.12.13 environment at: /usr
# Using Python 3.12.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    1.5 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# Checkpoint files will always be loaded safely.
# Total VRAM 14913 MB, total RAM 12976 MB
# pytorch version: 2.10.0+cu128
# xformers version: 0.0.35
# Set vram state to: LOW_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using async weight offloading with 2 streams
# Enabled pinned memory 11677.0
# working around nvidia conv3d memory bug.
# Using xformers attention
# aimdo: src/control.c:68:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14912 MB)
# DynamicVRAM support detected and enabled
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ComfyUI version: 0.20.3
# comfy-aimdo version: 0.2.14
# comfy-kitchen version: 0.2.8
# ComfyUI frontend version: 1.42.15
# [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# Asset seeder disabled
# ### Loading: ComfyUI-Impact-Subpack (V1.3.5)
# [Impact Pack/Subpack] Using folder_paths to determine whitelist path: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Pack/Subpack] Ensured whitelist directory exists: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack
# [Impact Pack/Subpack] Loaded 0 model(s) from whitelist: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Subpack] ultralytics_bbox: /content/ComfyUI/models/ultralytics/bbox
# [Impact Subpack] ultralytics_segm: /content/ComfyUI/models/ultralytics/segm
# ### Loading: ComfyUI-Manager (V3.40)
# [ComfyUI-Manager] network_mode: public
# [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# ### ComfyUI Revision: 5111 [491e8454] *DETACHED | Released on '2026-05-08'
#
# [rgthree-comfy] Loaded 48 fantastic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# ### Loading: ComfyUI-Impact-Pack (V8.28.3)
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [Impact Pack] Wildcard total size (0.00 MB) is within cache limit (50.00 MB). Using full cache mode.
# [Impact Pack] Wildcards loading done.
#
# Import times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui_fearnworksnodes
#    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-flux-continuum
#    0.2 seconds: /content/ComfyUI/custom_nodes/comfyui_essentials
#    0.2 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#    0.3 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    0.4 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-subpack
#    1.3 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-pack
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
# FETCH ComfyRegistry Data: 5/145
# FETCH ComfyRegistry Data: 10/145
# FETCH ComfyRegistry Data: 15/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/groupNode.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/clipspace.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 20/145
# FETCH ComfyRegistry Data: 25/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/buttonGroup.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/button.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 30/145
# FETCH ComfyRegistry Data: 35/145
# FETCH ComfyRegistry Data: 40/145
# FETCH ComfyRegistry Data: 45/145
# FETCH ComfyRegistry Data: 50/145
# FETCH ComfyRegistry Data: 55/145
# FETCH ComfyRegistry Data: 60/145
# FETCH ComfyRegistry Data: 65/145
# FETCH ComfyRegistry Data: 70/145
# FETCH ComfyRegistry Data: 75/145
# FETCH ComfyRegistry Data: 80/145
# FETCH ComfyRegistry Data: 85/145
# FETCH ComfyRegistry Data: 90/145
# FETCH ComfyRegistry Data: 95/145
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/746607195_github-stats.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/832903789_extras.json [DONE]
# FETCH ComfyRegistry Data: 100/145
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1742899825_extension-node-map.json [DONE]
# FETCH ComfyRegistry Data: 105/145
# FETCH ComfyRegistry Data: 110/145
# FETCH ComfyRegistry Data: 115/145
# FETCH ComfyRegistry Data: 120/145
#
# Updating: comfyui-impact-pack
# Updating: rgthree-comfy
# Updating: comfyui_essentials
# Updating: comfyui-impact-subpack
# Updating: comfyui-flux-continuum
# Updating: comfyui_fearnworksnodes
# [ComfyUI-Manager] Queued works are completed.
# {'update': 6}
#
# After restarting ComfyUI, please refresh the browser.
# FETCH ComfyRegistry Data: 125/145
# FETCH ComfyRegistry Data: 130/145
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--listen', '127.0.0.1', '--port', '8188', '--lowvram', '--preview-method', 'auto']
# setup plugin alembic.autogenerate.schemas
# setup plugin alembic.autogenerate.tables
# setup plugin alembic.autogenerate.types
# setup plugin alembic.autogenerate.constraints
# setup plugin alembic.autogenerate.defaults
# setup plugin alembic.autogenerate.comments
# [ComfyUI-Manager] Using `uv` as Python module for pip operations.
# Using Python 3.12.13 environment at: /usr
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-05-10 15:04:22.198
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# Using Python 3.12.13 environment at: /usr
# Using Python 3.12.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    1.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Checkpoint files will always be loaded safely.
# Total VRAM 14913 MB, total RAM 12976 MB
# pytorch version: 2.10.0+cu128
# xformers version: 0.0.35
# Set vram state to: LOW_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using async weight offloading with 2 streams
# Enabled pinned memory 11677.0
# working around nvidia conv3d memory bug.
# Using xformers attention
# aimdo: src/control.c:68:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14912 MB)
# DynamicVRAM support detected and enabled
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ComfyUI version: 0.20.3
# comfy-aimdo version: 0.2.14
# comfy-kitchen version: 0.2.8
# ComfyUI frontend version: 1.42.15
# [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# Asset seeder disabled
# ### Loading: ComfyUI-Impact-Subpack (V1.3.5)
# [Impact Pack/Subpack] Using folder_paths to determine whitelist path: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Pack/Subpack] Ensured whitelist directory exists: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack
# [Impact Pack/Subpack] Loaded 0 model(s) from whitelist: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Subpack] ultralytics_bbox: /content/ComfyUI/models/ultralytics/bbox
# [Impact Subpack] ultralytics_segm: /content/ComfyUI/models/ultralytics/segm
# ### Loading: ComfyUI-Manager (V3.40)
# [ComfyUI-Manager] network_mode: public
# [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# ### ComfyUI Revision: 5111 [491e8454] *DETACHED | Released on '2026-05-08'
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
#
# [rgthree-comfy] Loaded 48 epic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# ### Loading: ComfyUI-Impact-Pack (V8.28.3)
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [Impact Pack] Wildcard total size (0.00 MB) is within cache limit (50.00 MB). Using full cache mode.
# [Impact Pack] Wildcards loading done.
#
# Import times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-flux-continuum
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui_fearnworksnodes
#    0.1 seconds: /content/ComfyUI/custom_nodes/comfyui_essentials
#    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#    0.1 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    0.6 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-subpack
#    0.7 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-pack
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
# FETCH ComfyRegistry Data: 5/145
# FETCH ComfyRegistry Data: 10/145
# FETCH ComfyRegistry Data: 15/145
# FETCH ComfyRegistry Data: 20/145
# FETCH ComfyRegistry Data: 25/145
# FETCH ComfyRegistry Data: 30/145
# FETCH ComfyRegistry Data: 35/145
# FETCH ComfyRegistry Data: 40/145
# FETCH ComfyRegistry Data: 45/145
# FETCH ComfyRegistry Data: 50/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/groupNode.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 55/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/clipspace.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 60/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/buttonGroup.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/button.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 65/145
# FETCH ComfyRegistry Data: 70/145
# FETCH ComfyRegistry Data: 75/145
# FETCH ComfyRegistry Data: 80/145
# FETCH ComfyRegistry Data: 85/145
# FETCH ComfyRegistry Data: 90/145
# FETCH ComfyRegistry Data: 95/145
# FETCH ComfyRegistry Data: 100/145
# FETCH ComfyRegistry Data: 105/145
# FETCH ComfyRegistry Data: 110/145
# FETCH ComfyRegistry Data: 115/145
# FETCH ComfyRegistry Data: 120/145
# FETCH ComfyRegistry Data: 125/145
# FETCH ComfyRegistry Data: 130/145
# FETCH ComfyRegistry Data: 135/145
# FETCH ComfyRegistry Data: 140/145
# FETCH ComfyRegistry Data: 145/145
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# ERROR: To use this feature, you must either set '--listen' to a local IP and set the security level to 'normal-' or lower, or set the security level to 'middle' or 'weak'. Please contact the administrator.
# Reference: https://github.com/ltdrdata/ComfyUI-Manager#security-policy
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/4245046894_model-list.json [DONE]
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/746607195_github-stats.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/832903789_extras.json [DONE]
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/746607195_github-stats.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/832903789_extras.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1742899825_extension-node-map.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1742899825_extension-node-map.json [DONE]
#
# Updating: comfyui_fearnworksnodes
# Updating: comfyui_fearnworksnodes
# [ComfyUI-Manager] Queued works are completed.
# {'update': 2}
#
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--listen', '127.0.0.1', '--port', '8188', '--lowvram', '--preview-method', 'auto']
# setup plugin alembic.autogenerate.schemas
# setup plugin alembic.autogenerate.tables
# setup plugin alembic.autogenerate.types
# setup plugin alembic.autogenerate.constraints
# setup plugin alembic.autogenerate.defaults
# setup plugin alembic.autogenerate.comments
# [ComfyUI-Manager] Using `uv` as Python module for pip operations.
# Using Python 3.12.13 environment at: /usr
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-05-10 15:08:12.743
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# Using Python 3.12.13 environment at: /usr
# Using Python 3.12.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    2.5 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4']}
# Checkpoint files will always be loaded safely.
# Total VRAM 14913 MB, total RAM 12976 MB
# pytorch version: 2.10.0+cu128
# xformers version: 0.0.35
# Set vram state to: LOW_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using async weight offloading with 2 streams
# Enabled pinned memory 11677.0
# working around nvidia conv3d memory bug.
# Using xformers attention
# aimdo: src/control.c:68:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14912 MB)
# DynamicVRAM support detected and enabled
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ComfyUI version: 0.20.3
# comfy-aimdo version: 0.2.14
# comfy-kitchen version: 0.2.8
# ComfyUI frontend version: 1.42.15
# [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# Asset seeder disabled
# ### Loading: ComfyUI-Impact-Subpack (V1.3.5)
# [Impact Pack/Subpack] Using folder_paths to determine whitelist path: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Pack/Subpack] Ensured whitelist directory exists: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack
# [Impact Pack/Subpack] Loaded 0 model(s) from whitelist: /content/ComfyUI/user/default/ComfyUI-Impact-Subpack/model-whitelist.txt
# [Impact Subpack] ultralytics_bbox: /content/ComfyUI/models/ultralytics/bbox
# [Impact Subpack] ultralytics_segm: /content/ComfyUI/models/ultralytics/segm
# ### Loading: ComfyUI-Manager (V3.40)
# [ComfyUI-Manager] network_mode: public
# [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# ### ComfyUI Revision: 5111 [491e8454] *DETACHED | Released on '2026-05-08'
#
# [rgthree-comfy] Loaded 48 epic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# ### Loading: ComfyUI-Impact-Pack (V8.28.3)
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [Impact Pack] Wildcard total size (0.00 MB) is within cache limit (50.00 MB). Using full cache mode.
#
# Import times for custom nodes:
# [Impact Pack] Wildcards loading done.
#    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-flux-continuum
#    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui_essentials
#    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    0.1 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-subpack
#    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
#    0.3 seconds: /content/ComfyUI/custom_nodes/comfyui_fearnworksnodes
#    0.4 seconds: /content/ComfyUI/custom_nodes/comfyui-impact-pack
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
# FETCH ComfyRegistry Data: 5/145
# FETCH ComfyRegistry Data: 10/145
# FETCH ComfyRegistry Data: 15/145
# FETCH ComfyRegistry Data: 20/145
# FETCH ComfyRegistry Data: 25/145
# FETCH ComfyRegistry Data: 30/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/groupNode.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/clipspace.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 35/145
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/buttonGroup.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/button.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# FETCH ComfyRegistry Data: 40/145
# FETCH ComfyRegistry Data: 45/145
# FETCH ComfyRegistry Data: 50/145
# FETCH ComfyRegistry Data: 55/145
# FETCH ComfyRegistry Data: 60/145
# FETCH ComfyRegistry Data: 65/145
# FETCH ComfyRegistry Data: 70/145
# FETCH ComfyRegistry Data: 75/145
# FETCH ComfyRegistry Data: 80/145
# FETCH ComfyRegistry Data: 85/145
# FETCH ComfyRegistry Data: 90/145
# FETCH ComfyRegistry Data: 95/145
# FETCH ComfyRegistry Data: 100/145
# FETCH ComfyRegistry Data: 105/145
# FETCH ComfyRegistry Data: 110/145
# FETCH ComfyRegistry Data: 115/145
# FETCH ComfyRegistry Data: 120/145
# FETCH ComfyRegistry Data: 125/145
# FETCH ComfyRegistry Data: 130/145
# FETCH ComfyRegistry Data: 135/145
# FETCH ComfyRegistry Data: 140/145
# FETCH ComfyRegistry Data: 145/145
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_967/3000478158.py in <cell line: 0>()
#      80     process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
#      81
# ---> 82     for line in iter(process.stdout.readline, ''):
#      83         sys.stdout.write(line)
#      84         sys.stdout.flush()
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
#@title 5. Build Tarball Cache & Backup
#@markdown Compresses your local UI nodes into a single, high-speed archive and saves it to Drive. **Run this before disconnecting** so your next boot is instant.

import os
print("🔄 Compressing UI workspace into high-speed cache...")
WORKSPACE = "/content/ComfyUI"
CACHE_TAR = "/content/drive/MyDrive/ComfyUI/comfy_ui_cache.tar"

if os.path.exists(WORKSPACE):
    os.chdir(WORKSPACE)
    # !tar -cf "{CACHE_TAR}" custom_nodes user
    print(f"✅ Cache built and saved to: {CACHE_TAR}")
    print("✅ You may now safely disconnect your session.")
else:
    print("⚠️ ComfyUI workspace not found. Nothing to backup.")
